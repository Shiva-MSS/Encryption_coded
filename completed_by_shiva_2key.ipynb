# %% [markdown]
# # Casual Coded Correspondence: The Project
#
# In this project, you will be working to code and decode various messages between you and your fictional cryptography enthusiast pen pal Vishal. You and Vishal have been exchanging letters for quite some time now and have started to provide a puzzle in each one of your letters.  Here is his most recent letter:
#
#      Hey there! How have you been? I've been great! I just learned about this really cool type of cipher called a  Caesar Cipher. Here's how it works: You take your message, something like "hello" and then you shift all of the letters by a certain offset. For example, if I chose an offset of 3 and a message of "hello", I would code my message by shifting each letter 3 places to the left (with respect to the alphabet). So "h" becomes "e", "e" becomes, "b", "l" becomes "i", and "o" becomes "l". Then I have my coded message,"ebiil"! Now I can send you my message and the offset and you can decode it. The best thing is that Julius Caesar himself used this cipher, that's why it's called the Caesar Cipher! Isn't that so cool! Okay, now I'm going to send you a longer coded message that you have to decode yourself!
#
#         xuo jxuhu! jxyi yi qd unqcfbu ev q squiqh syfxuh. muhu oek qrbu je tusetu yj? y xefu ie! iudt cu q cuiiqwu rqsa myjx jxu iqcu evviuj!
#
#     This message has an offset of 10. Can you decode it?
#
#
# #### Step 1: Decode Vishal's Message
# In the cell below, use your Python skills to decode Vishal's message and print the result. Hint: you can account for shifts that go past the end of the alphabet using the modulus operator, but I'll let you figure out how!

# %%
Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuations =".,!?' "
Coded_message = "xuo jxuhu! jxyi yi qd unqcfbu ev q squiqh syfxuh. muhu oek qrbu je tusetu yj? y xefu ie! iudt cu q cuiiqwu rqsa myjx jxu iqcu evviuj!"
Decoded_message = ""

for letter in Coded_message:
  if not letter in punctuations:
      letter_index = Alphabets.find(letter)
      Decoded_message += Alphabets[(letter_index + 10)%26]
      
  else:
    Decoded_message += letter
    
print (Decoded_message)
# Out:
# hey there! this is an example of a caesar cipher. were you able to decode it? i hope so! send me a message back with the same offset!

# %% [markdown]
# #### Step 2: Send Vishal a Coded Message
# Great job! Now send Vishal back a message using the same offset. Your message can be anything you want! Remember, coding happens in opposite direction of decoding.

# %%
Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuations =".,!?' "
encoded_message = ""
message = "Hey Vishal, it was fun solving these 'code cipher excersie', i want dive further in to this!!, can i send secret messages to 'extraterristia' beings?."


for letter in message:
  if not letter in punctuations:
      letter_index = Alphabets.find(letter)
      encoded_message += Alphabets[(letter_index + 10)%26]
      
  else:
    encoded_message += letter
    
print (encoded_message)
# Out:
# joi jscrkv, sd gkc pex cyvfsxq droco 'myno mszrob ohmobcso', s gkxd nsfo pebdrob sx dy drsc!!, mkx s coxn combod wocckqoc dy 'ohdbkdobbscdsk' losxqc?.

# %% [markdown]
# #### Step 3: Make functions for decoding and coding
#
# Vishal sent over another reply, this time with two coded messages!
#
#     You're getting the hang of this! Okay here are two more messages, the first one is coded just like before with  an offset of ten, and it contains the hint for decoding the second message!
#
#     First message:
#
#         jxu evviuj veh jxu iusedt cuiiqwu yi vekhjuud.
#
#     Second message:
#
#         bqdradyuzs ygxfubxq omqemd oubtqde fa oapq kagd yqeemsqe ue qhqz yadq eqogdq!
#
# Decode both of these messages.
#
# If you haven't already, define two functions `decoder(message, offset)` and `coder(message, offset)` that can be used to quickly decode and code messages given any offset.

# %%
Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuations =".,!?' "
def decoder (message, offset):
    Decoded_message =""
    for letter in message:
        if not letter in punctuations:
            letter_index = Alphabets.find(letter)
            Decoded_message += Alphabets[(letter_index + offset)%26]
        else:
            Decoded_message += letter
    return Decoded_message
message = "vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl tl hulhexmx. px'ee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx"



print(decoder(message, 7))
# Out:
# computers have rendered all of these old ciphers as obsolete. we'll have to really step up our game if we want to keep our messages safe

# %%
def coder (message, offset):
    encoded_message = ""
    
    for letter in message:
        if not letter in punctuations:
            letter_index = Alphabets.find(letter)
            encoded_message += Alphabets[(letter_index - offset)%26]
        else:
            encoded_message += letter
    return encoded_message

message = "hey Shivam! this code cipher is wonderfull and challenging if you have time try to complete it, it's worth it!"
message_2 = "Hey! Sony wey nachedhey sony nachedhey!"
message_2 = "I know it is kind easy when you know what method is it encoded in, but know things change, this one might be a litter harder but let me know how did it feel"

print(coder(message, 15))
print(coder(message_2, 15))
print(decoder(message_2, 7))
# Out:
# spj kstglx! estd nzop ntaspc td hzyopcqfww lyo nslwwpyrtyr tq jzf slgp etxp ecj ez nzxawpep te, te'd hzces te!
# k vyzh te td vtyo pldj hspy jzf vyzh hsle xpeszo td te pynzopo ty, mfe vyzh estyrd nslyrp, estd zyp xtrse mp l wteepc slcopc mfe wpe xp vyzh szh oto te qppw
# g ruvd pa pz rpuk lhzf dolu fvb ruvd doha tlaovk pz pa lujvklk pu, iba ruvd aopunz johunl, aopz vul tpnoa il h spaaly ohykly iba sla tl ruvd ovd kpk pa mlls

# %% [markdown]
# #### Step 4: Solving a Caesar Cipher without knowing the shift value
#
# Awesome work! While you were working to decode his last two messages, Vishal sent over another letter! He's really been bitten by the crytpo-bug. Read it and see what interesting task he has lined up for you this time.
#
#             Hello again friend! I knew you would love the Caesar Cipher, it's a cool simple way to encrypt messages. Did you know that back in Caesar's time, it was considered a very secure way of communication and it took a lot of effort to crack if you were unaware of the value of the shift? That's all changed with computers! Now we can brute force these kinds of ciphers very quickly, as I'm sure you can imagine.
#
#             To test your cryptography skills, this next coded message is going to be harder than the last couple to crack. It's still going to be coded with a Caesar Cipher but this time I'm not going to tell you the value of   the shift. You'll have to brute force it yourself.
#
#             Here's the coded message:
#
#             vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl tl hulhexmx. px'ee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx.
#
#             Good luck!
#
# Decode Vishal's most recent message and see what it says!

# %%
Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuations =".,!?' "

def decoder (message, offset):
    Decoded_message =""
    for letter in message:
        if not letter in punctuations:
            letter_index = Alphabets.find(letter)
            Decoded_message += Alphabets[(letter_index + offset)%26]
        else:
            Decoded_message += letter
    return Decoded_message
    
def coder (message, offset):
    encoded_message = ""
    
    for letter in message:
        if not letter in punctuations:
            letter_index = Alphabets.find(letter)
            encoded_message += Alphabets[(letter_index - offset)%26]
        else:
            encoded_message += letter
    return encoded_message
 
message_1 ="jxu evviuj veh jxu iusedt cuiiqwu yi vekhjuud."
message_two = "bqdradyuzs ygxfubxq omqemd oubtqde fa oapq kagd yqeemsqe ue qhqz yadq eqogdq!"
message_3 = "vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl tl hulhexmx. px'ee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx."
print(decoder(message_1, 10))
print(decoder(message_two, 14))
for i in range(0, 10):
    print("This is for an offset of: "+str(i)+" ")
    print(decoder(message_3,i))
# Out:
# the offset for the second message is fourteen.
# performing multiple caesar ciphers to code your messages is even more secure!
# This is for an offset of: 0
# vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl tl hulhexmx. px'ee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx.
# This is for an offset of: 1
# wigjonylm bupy lyhxylyx uff iz nbymy ifx wcjbylm um ivmifyny. qy'ff bupy ni lyuffs mnyj oj iol augy cz qy quhn ni eyyj iol gymmuaym muzy.
# This is for an offset of: 2
# xjhkpozmn cvqz mziyzmzy vgg ja ocznz jgy xdkczmn vn jwnjgzoz. rz'gg cvqz oj mzvggt nozk pk jpm bvhz da rz rvio oj fzzk jpm hznnvbzn nvaz.
# This is for an offset of: 3
# ykilqpano dwra najzanaz whh kb pdaoa khz yeldano wo kxokhapa. sa'hh dwra pk nawhhu opal ql kqn cwia eb sa swjp pk gaal kqn iaoowcao owba.
# This is for an offset of: 4
# zljmrqbop exsb obkaboba xii lc qebpb lia zfmebop xp lyplibqb. tb'ii exsb ql obxiiv pqbm rm lro dxjb fc tb txkq ql hbbm lro jbppxdbp pxcb.
# This is for an offset of: 5
# amknsrcpq fytc pclbcpcb yjj md rfcqc mjb agnfcpq yq mzqmjcrc. uc'jj fytc rm pcyjjw qrcn sn msp eykc gd uc uylr rm iccn msp kcqqyecq qydc.
# This is for an offset of: 6
# bnlotsdqr gzud qdmcdqdc zkk ne sgdrd nkc bhogdqr zr narnkdsd. vd'kk gzud sn qdzkkx rsdo to ntq fzld he vd vzms sn jddo ntq ldrrzfdr rzed.
# This is for an offset of: 7
# computers have rendered all of these old ciphers as obsolete. we'll have to really step up our game if we want to keep our messages safe.
# This is for an offset of: 8
# dpnqvufst ibwf sfoefsfe bmm pg uiftf pme djqifst bt pctpmfuf. xf'mm ibwf up sfbmmz tufq vq pvs hbnf jg xf xbou up lffq pvs nfttbhft tbgf.
# This is for an offset of: 9
# eqorwvgtu jcxg tgpfgtgf cnn qh vjgug qnf ekrjgtu cu qduqngvg. yg'nn jcxg vq tgcnna uvgr wr qwt icog kh yg ycpv vq mggr qwt oguucigu uchg.

# %% [markdown]
# #### Step 5: The Vigenère Cipher
#
# Great work! While you were working on the brute force cracking of the cipher, Vishal sent over another letter. That guy is a letter machine!
#
#             Salutations! As you can see, technology has made brute forcing simple ciphers like the Caesar Cipher extremely easy, and us crypto-enthusiasts have had to get more creative and use more complicated ciphers. This next cipher I'm going to teach you is the Vigenère Cipher, invented by an Italian cryptologist named Giovan Battista Bellaso (cool name eh?) in the 16th century, but named after another cryptologist from the 16th century, Blaise de Vigenère.
#
#            The Vigenère Cipher is a polyalphabetic substitution cipher, as opposed to the Caesar Cipher which was a monoalphabetic substitution cipher. What this means is that opposed to having a single shift that is applied to every letter, the Vigenère Cipher has a different shift for each individual letter. The value of the shift for each letter is determined by a given keyword.
#
#            Consider the message
#
#                barry is the spy
#
#            If we want to code this message, first we choose a keyword. For this example, we'll use the keyword
#
#                dog
#
#            Now we use the repeat the keyword over and over to generate a _keyword phrase_ that is the same length as the message we want to code. So if we want to code the message "barry is the spy" our _keyword phrase_ is "dogdo gd ogd ogd". Now we are ready to start coding our message. We shift the each letter of our message by the place value of the corresponding letter in the keyword phrase, assuming that "a" has a place value of 0, "b" has a place value of 1, and so forth. Remember, we zero-index because this is Python we're talking about!
#
#                         message:       b  a  r  r  y    i  s   t  h  e   s  p  y
#
#                  keyword phrase:       d  o  g  d  o    g  d   o  g  d   o  g  d
#
#           resulting place value:       4  14 15 12 16   24 11  21 25 22  22 17 5
#
#             So we shift "b", which has an index of 1, by the index of "d", which is 3. This gives us an place value of 4, which is "e". Then continue the trend: we shift "a" by the place value of "o", 14, and get "o" again, we shift "r" by the place value of "g", 15, and get "x", shift the next "r" by 12 places and "u", and so forth. Once we complete all the shifts we end up with our coded message:
#
#                 eoxum ov hnh gvb
#
#             As you can imagine, this is a lot harder to crack without knowing the keyword! So now comes the hard part. I'll give you a message and the keyword, and you'll see if you can figure out how to crack it! Ready? Okay here's my message:
#
#                 dfc aruw fsti gr vjtwhr wznj? vmph otis! cbx swv jipreneo uhllj kpi rahjib eg fjdkwkedhmp!
#
#             and the keyword to decode my message is
#
#                 friends
#
#             Because that's what we are! Good luck friend!
#
# And there it is. Vishal has given you quite the assignment this time! Try to decode his message. It may be helpful to create a function that takes two parameters, the coded message and the keyword and then work towards a solution from there.
#
# **NOTE:** Watch out for spaces and punctuation! When there's a space or punctuation mark in the original message, there should be a space/punctuation mark in the corresponding repeated-keyword string as well!

# %%
## this is the actual coded cipher:
Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuations = ".,!?' "
def vigenere_decoder(coded_message, keyword):
    letter_pointer = 0
    keyword_final = ''
    for i in range(0,len(coded_message)):
        if coded_message[i] in punctuations:
            keyword_final += coded_message[i]
        else:
            keyword_final += keyword[letter_pointer]
            letter_pointer = (letter_pointer+1)%len(keyword)
    translated_message = ''
    for i in range(0,len(coded_message)):    
        if not coded_message[i] in punctuations:
            ln = Alphabet.find(coded_message[i]) - Alphabet.find(keyword_final[i])
            translated_message += Alphabet[ln % 26]
        else:
            translated_message += coded_message[i]
    return translated_message

message = "dfc aruw fsti gr vjtwhr wznj? vmph otis! cbx swv jipreneo uhllj kpi rahjib eg fjdkwkedhmp!"
keyword = "friends"

print(vigenere_decoder(message, keyword))



##Shiva's modification to Vignere cipher:

Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuation = ".,?'! "
                                                           
def Vigenere_cipher_decoder(message, keyword, keyword2):
    keyword_pointer = 0
    keyword_final = ""
    for i in range(0, len(message)):
        if message[i] in punctuations:
            keyword_final += message[i]
        else:
            keyword_final += keyword[keyword_pointer]
            keyword_pointer = (keyword_pointer+1)%len(keyword)
    letter_pointer2 = 0
    keyword_final2 = ''        
    for i in range(0, len(message)):
        if message[i] in punctuations:
            keyword_final2 += message[i]
        else:
            keyword_final2 += keyword2[letter_pointer2]
            letter_pointer2 = (letter_pointer2+1)%len(keyword2)
    ### this is basicially the combination of 2 key words          
    translated_message = ""
    for i in range(0, len(message)):
        if not message[i] in punctuations:
            SV = Alphabets.find(message[i]) - Alphabets.find(keyword_final[i]) - Alphabets.find(keyword_final2[i])
            translated_message += Alphabets[(SV%26)]
        else:
            translated_message += message[i]
    return translated_message    


message = "yoy're the best, guruji thosi great ho, thanks for all the help"
keyword = "learners"

message_2 = "Endhi sruthi Em chestunnavu eppudu enthry na, how is your health!!"
Keyword_2 = "dosthulu"

message_3 = "what are you pallning to eat for breakfast"
Keyword_3 = "roomates"

message_4 = "it is intresting but i wanna know, how exactly it works and we don't have butter!!"

Keyword_4 = "ghjdkfs"

message_5 = "r fokn hw ic hdqp qrtk njcm ygx qllh jiuq zxdgcg ww qz cnslydy cm, dex azxr udzmjs mevqsq, kiuj qld majnr yp n mcqgeo gouriz hst bbo lz emqg lei mde ek ehev"
message_6 = " y ypj'k jqog tcdf'e nsaei ztt s okrqpe jm zbfsmu xbifvccjbykt"

#print(Vigenere_cipher(message, keyword))

#print(Vigenere_cipher(message_2, Keyword_2))

#print(Vigenere_cipher(message_3, Keyword_3))

#print(Vigenere_cipher(message_4, Keyword_4))
print(Vigenere_cipher_decoder(message_5, Keyword_4, Keyword_2))
print(Vigenere_cipher_decoder(message_6, Keyword_4, Keyword_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 25>()
#      22 message = "dfc aruw fsti gr vjtwhr wznj? vmph otis! cbx swv jipreneo uhllj kpi rahjib eg fjdkwkedhmp!"
#      23 keyword = "friends"
# ---> 25 print(vigenere_decoder(message, keyword))
#      29 ##Shiva's modification to Vignere cipher:
#      31 Alphabet = "abcdefghijklmnopqrstuvwxyz"
#
# Input In [5], in vigenere_decoder(coded_message, keyword)
#      14 for i in range(0,len(coded_message)):
#      15     if not coded_message[i] in punctuations:
# ---> 16         ln = Alphabet.find(coded_message[i]) - Alphabet.find(keyword_final[i])
#      17         translated_message += Alphabet[ln % 26]
#      18     else:
#
# NameError: name 'Alphabet' is not defined

# %% [markdown]
# #### Step 6: Send a message with the  Vigenère Cipher
# Great work decoding the message. For your final task, write a function that can encode a message using a given keyword and write out a message to send to Vishal!
#
# *As a bonus, try calling your decoder function on the result of your encryption function. You should get the original message back!*

# %%
Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuations = ".,!?' "

def vigenere_coder(message, keyword):
    letter_pointer = 0
    keyword_final = ''
    for i in range(0,len(message)):
        if message[i] in punctuation:
            keyword_final += message[i]
        else:
            keyword_final += keyword[letter_pointer]
            letter_pointer = (letter_pointer+1)%len(keyword)
    translated_message = ''
    for i in range(0,len(message)):
        if message[i] not in punctuations:
            ln = alphabet.find(message[i]) + alphabet.find(keyword_final[i])
            translated_message += alphabet[ln % 26]
        else:
            translated_message += message[i]
    return translated_message

message_for_v = "thanks for teaching me all these cool ciphers! you really are the best!"
keyword = "besties"

print(vigenere_coder(message_for_v,keyword))
print(vigenere_decoder(vigenere_coder(message_for_v, keyword), keyword))


## SHIVA's Modification to Vignere Cipher:
Alphabets = "abcdefghijklmnopqrstuvwxyz"
punctuations = ".,!?' "
def Vigenere_cipher_coder(message, keyword, keyword2):
    keyword_pointer = 0
    keyword_final = ""
    for i in range(0, len(message)):
        if message[i] in punctuations:
            keyword_final += message[i]
        else:
            keyword_final += keyword[keyword_pointer]
            keyword_pointer = (keyword_pointer+1)%len(keyword)
    letter_pointer2 = 0
    keyword_final2 = ''        
    for i in range(0, len(message)):
        if message[i] in punctuations:
            keyword_final2 += message[i]
        else:
            keyword_final2 += keyword2[letter_pointer2]
            letter_pointer2 = (letter_pointer2+1)%len(keyword2)
    translated_message = ""
    for i in range(0, len(message)):
        if not message[i] in punctuations:
            SV = Alphabets.find(message[i]) + Alphabets.find(keyword_final[i]) + Alphabets.find(keyword_final2[i])
            translated_message += Alphabets[(SV%26)]
        else:
            translated_message += message[i]
    return translated_message    


message = "yoy're the best, guruji thosi great ho, thanks are all the help"
keyword = "learners"

message_2 = "Endhi sunny Em chestunnavu eppudu enthry na, how is your health!!"
Keyword_2 = "dosthulu"

message_3 = "what are you pallning to eat for breakfast"
Keyword_3 = "roomates"

message_4 = "it is intresting but i wanna know, how exactly it works and we don't have butter!!"

Keyword_4 = "ghjdkfs"

message_5 = "i know it is kind easy when you know what method is it encoded in, but know things change, this one might be a little harder but let me know how did it feel "

message_6= " p don't know what's wrong but a letter is coming unexpectedly"

#print(Vigenere_cipher(message, keyword))

#print(Vigenere_cipher(message_2, Keyword_2))

#print(Vigenere_cipher(message_3, Keyword_3))

#print(Vigenere_cipher(message_4, Keyword_4))
print(Vigenere_cipher_coder(message_5, Keyword_4, Keyword_2))

print(Vigenere_cipher_coder(message_6, Keyword_4, Keyword_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 22>()
#      19 message_for_v = "thanks for teaching me all these cool ciphers! you really are the best!"
#      20 keyword = "besties"
# ---> 22 print(vigenere_coder(message_for_v,keyword))
#      23 print(vigenere_decoder(vigenere_coder(message_for_v, keyword), keyword))
#      26 ## SHIVA's Modification to Vignere Cipher:
#
# Input In [1], in vigenere_coder(message, keyword)
#       3 keyword_final = ''
#       4 for i in range(0,len(message)):
# ----> 5     if message[i] in punctuation:
#       6         keyword_final += message[i]
#       7     else:
#
# NameError: name 'punctuation' is not defined

# %% [markdown]
# #### Conclusion
# Over the course of this project you've learned about two different cipher methods and have used your Python skills to code and decode messages. There are all types of other facinating ciphers out there to explore, and Python is the perfect language to implement them with, so go exploring!
